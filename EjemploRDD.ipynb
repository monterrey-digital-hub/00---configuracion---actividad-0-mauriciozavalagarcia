# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 42 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 81.8 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=dfc3f3477f1aca900e003720d4870a5e0d19da5787254340d773d8e9a3707acb
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %%
from pyspark import SparkContext
sc = SparkContext("local", "first app")

# %%
pyfile = "drive/MyDrive/pyfile.txt"
logdata = sc.textFile(pyfile)

# %%
type(sc.textFile(pyfile))
# Out:
# pyspark.rdd.RDD

# %%
print(logdata)
# Out:
# drive/MyDrive/pyfile.txt MapPartitionsRDD[25] at textFile at NativeMethodAccessorImpl.java:0

# %%
logDataImp = logdata.collect()

# %% [markdown]
# # New Section
